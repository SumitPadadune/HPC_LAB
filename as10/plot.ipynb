# %%
# %pip install numpy matplotlib
# Out:
# ...
#   Using cached numpy-2.1.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.7/163.7 kB 3.1 MB/s eta 0:00:00a 0:00:01
# ...
# Using cached numpy-2.1.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 4.4 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.5/320.5 kB 3.6 MB/s eta 0:00:00a 0:00:01
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 4.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 5.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 6.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.9/106.9 kB 9.2 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# ...

# %%
import matplotlib.pyplot as plt

# Number of processes and corresponding broadcast times (replace with your data)
num_processes = [1, 2, 3, 4, 5]
broadcast_times = [0.000001, 0.001176, 0.001624, 0.001888, 0.001878]  # Sample data, replace with actual

plt.figure(figsize=(8, 6))
plt.plot(num_processes, broadcast_times, marker='o', linestyle='-', color='b')
plt.title('MPI_Bcast Performance with Fixed Message Size')
plt.xlabel('Number of Processes')
plt.ylabel('Time for Broadcast (seconds)')
plt.grid(True)
plt.show()
